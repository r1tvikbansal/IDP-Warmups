# %% [markdown]
# Work through Lesson 19 here and follow along running the code below (no need to download anything else)
#
# https://cse163.github.io/book/module-7-geospatial-data/lesson-19-geospatial-data-misc-python/introduction-to-geospatial-data.html

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# This special line allows graphs to appear here
# %matplotlib inline

# This is a relative path to the data
df = gpd.read_file('ne_110m_admin_0_countries.shp')

print('===== Columns =====')
print(df.columns)

# Print out one row of data
print('===== First row =====')
print(df.loc[0])
# Out:
# ===== Columns =====
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'ADMIN', 'ADM0_A3', 'GEOU_DIF', 'GEOUNIT',
#        'GU_A3', 'SU_DIF', 'SUBUNIT', 'SU_A3', 'BRK_DIFF', 'NAME', 'NAME_LONG',
#        'BRK_A3', 'BRK_NAME', 'BRK_GROUP', 'ABBREV', 'POSTAL', 'FORMAL_EN',
#        'FORMAL_FR', 'NAME_CIAWF', 'NOTE_ADM0', 'NOTE_BRK', 'NAME_SORT',
#        'NAME_ALT', 'MAPCOLOR7', 'MAPCOLOR8', 'MAPCOLOR9', 'MAPCOLOR13',
#        'POP_EST', 'POP_RANK', 'GDP_MD_EST', 'POP_YEAR', 'LASTCENSUS',
#        'GDP_YEAR', 'ECONOMY', 'INCOME_GRP', 'WIKIPEDIA', 'FIPS_10_', 'ISO_A2',
#        'ISO_A3', 'ISO_A3_EH', 'ISO_N3', 'UN_A3', 'WB_A2', 'WB_A3', 'WOE_ID',
#        'WOE_ID_EH', 'WOE_NOTE', 'ADM0_A3_IS', 'ADM0_A3_US', 'ADM0_A3_UN',
#        'ADM0_A3_WB', 'CONTINENT', 'REGION_UN', 'SUBREGION', 'REGION_WB',
#        'NAME_LEN', 'LONG_LEN', 'ABBREV_LEN', 'TINY', 'HOMEPART', 'MIN_ZOOM',
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

df = gpd.read_file('ne_110m_admin_0_countries.shp')

df.plot()
# Out:
# <Axes: >

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

df = gpd.read_file('ne_110m_admin_0_countries.shp')

# POP_EST is the name of the colummn containing population information
# legend=True makes the legend appear
df.plot(column='POP_EST', legend=True)

print(df['geometry'][0])
# Out:
# MULTIPOLYGON (((180 -16.06713266364245, 180 -16.5552165666392, 179.3641426619641 -16.80135407694688, 178.7250593629971 -17.01204167436804, 178.5968385951171 -16.63915, 179.0966093629971 -16.4339842775474, 179.4135093629971 -16.3790542775474, 180 -16.06713266364245)), ((178.12557 -17.50481, 178.3736 -17.33992, 178.71806 -17.62846, 178.55271 -18.15059, 177.93266 -18.28799, 177.38146 -18.16432, 177.28504 -17.72465, 177.67087 -17.38114, 178.12557 -17.50481)), ((-179.7933201090486 -16.02088225674122, -179.9173693847653 -16.5017831356494, -180 -16.5552165666392, -180 -16.06713266364245, -179.7933201090486 -16.02088225674122)))

# %% [markdown]
# # Part 1
# The name of this method, and the type of data structure returned by `gpd.read_file('geo_data/ne_110m_admin_0_countries.shp')` is important to note. The type == `<class 'geopandas.geodataframe.GeoDataFrame'>`. The method name is `read_file` which is ever so slightly different from `read_csv`.
#
# **Q1 What is the significance of the type?**
# > your answer here

# %% [markdown]
# **Q2. Examine shp data columns**
#
# Now that you've looked at some of the data after loading the shp file. Create a pandas data frame that has two coluns. One that includes a column for the name of the country and another for the population of that country. Print the head of this data below.
